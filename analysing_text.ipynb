# %% [markdown]
# # T2 - Text Analysis using Natural Language Processing

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ## Database
# [Manchetes Brasil Data Folha](https://github.com/pdpcosta/manchetesBrasildatabase)

# %%
from nltk.book import *

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1.concordance
# Out:
# <bound method Text.concordance of <Text: Moby Dick by Herman Melville 1851>>

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
from urllib.request import urlopen
import pandas as pd
import numpy as np

# %%
dataUrl = 'https://github.com/pdpcosta/manchetesBrasildatabase/blob/master/manchetesBrasildatabase.csv'

# %%
noticias = urlopen(dataUrl)
noticias

# %%
#data = open(noticias, mode="r", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-dceee48935b9> in <module>()
# ----> 1 data = open(noticias, mode="r", encoding="utf-8")
#
# TypeError: expected str, bytes or os.PathLike object, not HTTPResponse

# %%
data = pd.read_table(dataUrl, sep=',')

# %%
#a_noticias = pd.read_csv(noticias, sep=",")
data = pd.read_csv(noticias, sep=",")

# %%
# encoding: utf-8
# encoding: iso-8859-1
# encoding: win-1252
data = open('outro.csv')

# %%
ref_arquivo = open("outro.csv", mode="r", encoding="utf-8")
saida = open("saida.csv", mode="w", encoding="utf-8")

for linha in ref_arquivo:
    lista = []
    
    texto1 = str(linha)
    
    texto1 = texto1.replace(",","|")
    
    valores = texto1.split("|")

    if len(valores) > 5:
        text = ""
        #print("entrou")
        count = 4
        while count < len(valores):
            #print("entrou..")
            #print(str(len(valores)))
            text += valores[count]
            if (count < len(valores)-1):
                text += ", "
            count+=1
        #print(text)
        valores[4] = text
        
    completo = valores[0] + " | " + valores[1] + " | " + valores[2] + " | " + valores[3] + " | " + valores[4]
    
    saida.write(completo)

ref_arquivo.close()
saida.close()

# %%
#noticias

# %%
data = pd.read_csv("saida.csv",header=None, sep="|")

# %%
data.columns = ['Dia', 'Mês', 'Ano', 'Jornal', 'Título']

# %%
data
# Out:
#      Dia            Mês   Ano      Jornal  \
# 0      1   'fevereiro'   2017    'Valor'
# 1      1   'fevereiro'   2017    'Valor'
# 2      1   'fevereiro'   2017    'Valor'
# 3      1   'fevereiro'   2017    'Valor'
# 4      1   'fevereiro'   2017    'Valor'
# 5      1   'fevereiro'   2017    'Valor'
# 6      1   'fevereiro'   2017    'Valor'
# 7      1   'fevereiro'   2017    'Globo'
# 8      1   'fevereiro'   2017    'Globo'
# 9      1   'fevereiro'   2017    'Globo'
# 10     1   'fevereiro'   2017    'Globo'
# 11     1   'fevereiro'   2017    'Globo'
# 12     1   'fevereiro'   2017    'Globo'
# 13     1   'fevereiro'   2017    'Globo'
# 14     1   'fevereiro'   2017    'Folha'
# 15     1   'fevereiro'   2017    'Folha'
# 16     1   'fevereiro'   2017    'Folha'
# 17     1   'fevereiro'   2017    'Folha'
# 18     1   'fevereiro'   2017    'Folha'
# 19     1   'fevereiro'   2017    'Folha'
# 20     1   'fevereiro'   2017    'Folha'
# 21     1   'fevereiro'   2017    'Folha'
# ...

# %%
import nltk
for i, row in data.iterrows():
    tokens= nltk.word_tokenize(row["Título"])
    #print(tokens)

# %%
sentenca = data[0:1]
sentenca
# Out:
#    Dia            Mês   Ano     Jornal  \
# 0    1   'fevereiro'   2017   'Valor'
#
#                                               Título
# 0   'BNDES encolhe e volta ao nível de 20 anos at...

# %%
exemplo = str(data[0:6]['Título'])
tokens= nltk.word_tokenize(exemplo)
print(tokens)
# Out:
# ['0', "'BNDES", 'encolhe', 'e', 'volta', 'ao', 'nível', 'de', '20', 'anos', 'at', '...', '1', "'BC", 'cria', 'novo', 'instrumento', 'de', 'política', 'monetár', '...', '2', "'Câmbio", 'gera', 'bate-boca', 'entre', 'UA', 'e', 'UE', '.', "'", '3', "'Indenização", 'a', 'transmissoras', 'de', 'energia', 'já', 'ch', '...', '4', "'Políticos", 'esperam', 'que', 'relator', 'separe', '``', 'joio', 'd', '...', '5', "'Philips", 'quer', 'administrar', 'hospitais', 'públicos', '...', 'Name', ':', 'Título', ',', 'dtype', ':', 'object']

# %%
from nltk.corpus import stopwords

stopwords.words('portuguese')
# Out:
# ['de',
#  'a',
#  'o',
#  'que',
#  'e',
#  'do',
#  'da',
#  'em',
#  'um',
#  'para',
#  'com',
#  'não',
#  'uma',
#  'os',
#  'no',
#  'se',
#  'na',
#  'por',
#  'mais',
#  'as',
#  'dos',
#  'como',
#  'mas',
#  'ao',
#  'ele',
#  'das',
#  'à',
#  'seu',
#  'sua',
#  'ou',
#  'quando',
#  'muito',
#  'nos',
#  'já',
#  'eu',
#  'também',
#  'só',
#  'pelo',
#  'pela',
#  'até',
#  'isso',
#  'ela',
#  'entre',
#  'depois',
#  'sem',
#  'mesmo',
#  'aos',
#  'seus',
#  'quem',
#  'nas',
#  'me',
#  'esse',
#  'eles',
#  'você',
#  'essa',
#  'num',
#  'nem',
#  'suas',
#  'meu',
#  'às',
#  'minha',
#  'numa',
#  'pelos',
#  'elas',
#  'qual',
#  'nós',
#  'lhe',
#  'deles',
#  'essas',
#  'esses',
#  'pelas',
#  'este',
#  'dele',
#  'tu',
#  'te',
#  'vocês',
#  'vos',
#  'lhes',
#  'meus',
#  'minhas',
#  'teu',
#  'tua',
#  'teus',
#  'tuas',
#  'nosso',
#  'nossa',
#  'nossos',
#  'nossas',
#  'dela',
#  'delas',
#  'esta',
#  'estes',
#  'estas',
#  'aquele',
# ...

# %%
#Remover as stopwords

stop_words = [x for x in stopwords.words('portuguese') ]

#Navegando no conjunto de dados
for i, row in data.iterrows(): 
    
    sentenca2 =str(row['Título']).lower()
    t2s = sentenca2.split()
    
    for t1 in t2s:
        if  t1 in stop_words:
            print("has")
        else:
            print("doesn't have")
        
stop_words
# Out:
# doesn't have
# doesn't have
# has
# doesn't have
# has
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# has
# doesn't have
# doesn't have
# has
# doesn't have
# has
# doesn't have
# has
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# has
# doesn't have
# doesn't have
# has
# doesn't have
# doesn't have
# doesn't have
# doesn't have
# has
# doesn't have
# ...

# %%
palavras = (data.get_value (1, 'Título')).lower()
palavrasSemAspas = palavras.replace("'", "")
tokens = nltk.word_tokenize(palavrasSemAspas)
fd = nltk.FreqDist(tokens)

len(fd)
# Out:
# 8

# %%
nltk.corpus.mac_morpho.words()
tsents = nltk.corpus.mac_morpho.tagged_sents()
tsents = [[(w.lower(),simplify_tag(t)) for (w,t) in sent] for sent in tsents if sent]
train = tsents[100:]
test = tsents[:100]

####################

tagger0 = nltk.DefaultTagger("N")
nltk.accuracy(tagger0,test)

# %%
from nltk.stem import RSLPStemmer
stemmer = RSLPStemmer()
stemmer.stem('copiar')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-132-97fef324af1b> in <module>()
#       1 from nltk.stem import RSLPStemmer
# ----> 2 stemmer = RSLPStemmer()
#       3 stemmer.stem('copiar')
#
# C:\Users\TalitaCypriano\Anaconda3\lib\site-packages\nltk\stem\rslp.py in __init__(self)
#      56         self._model = []
#      57
# ---> 58         self._model.append( self.read_rule("step0.pt") )
#      59         self._model.append( self.read_rule("step1.pt") )
#      60         self._model.append( self.read_rule("step2.pt") )
#
# C:\Users\TalitaCypriano\Anaconda3\lib\site-packages\nltk\stem\rslp.py in read_rule(self, filename)
#      65
#      66     def read_rule (self, filename):
# ---> 67         rules = load('nltk:stemmers/rslp/' + filename, format='raw').decode("utf8")
#      68         lines = rules.split("\n")
#      69
#
# ...

# %%
nltk.corpus.mac_morpho.sents()
# Out:
# [['Jersei', 'atinge', 'média', 'de', 'Cr$', '1,4', 'milhão', 'em', 'a', 'venda', 'de', 'a', 'Pinhal', 'em', 'São', 'Paulo'], ['Programe', 'sua', 'viagem', 'a', 'a', 'Exposição', 'Nacional', 'do', 'Zebu', ',', 'que', 'começa', 'dia', '25'], ...]

# %%
nltk.corpus.mac_morpho.tagged_words()
# Out:
# [('Jersei', 'N'), ('atinge', 'V'), ('média', 'N'), ...]

# %%
nltk.corpus.mac_morpho.tagged_sents()
# Out:
# [[('Jersei', 'N'), ('atinge', 'V'), ('média', 'N'), ('de', 'PREP'), ('Cr$', 'CUR'), ('1,4', 'NUM'), ('milhão', 'N'), ('em', 'PREP|+'), ('a', 'ART'), ('venda', 'N'), ('de', 'PREP|+'), ('a', 'ART'), ('Pinhal', 'NPROP'), ('em', 'PREP'), ('São', 'NPROP'), ('Paulo', 'NPROP')], [('Programe', 'V'), ('sua', 'PROADJ'), ('viagem', 'N'), ('a', 'PREP|+'), ('a', 'ART'), ('Exposição', 'NPROP'), ('Nacional', 'NPROP'), ('do', 'NPROP'), ('Zebu', 'NPROP'), (',', ','), ('que', 'PRO-KS-REL'), ('começa', 'V'), ('dia', 'N'), ('25', 'N|AP')], ...]

# %%
para = "Hello World. It's good to see you. Thanks for buying this book."
from nltk.tokenize import sent_tokenize
sent_tokenize(para)
# Out:
# ['Hello World.', "It's good to see you.", 'Thanks for buying this book.']

# %%
spanish_tokenizer = nltk.data.load('tokenizers/punkt/spanish.pickle')

# %%
spanish_tokenizer.tokenize('Hola amigo. Estoy bien.')
# Out:
# ['Hola amigo.', 'Estoy bien.']

# %%
portuguese_tokenizer = nltk.data.load('tokenizers/punkt/portuguese.pickle')

# %%
portuguese_tokenizer.tokenize('Oi amigo! Tudo bem?')
# Out:
# ['Oi amigo!', 'Tudo bem?']

# %%
from nltk.tokenize import word_tokenize
word_tokenize('Hello World.')
# Out:
# ['Hello', 'World', '.']

# %%
from nltk.corpus import floresta

# %%
floresta.words()
# Out:
# ['Um', 'revivalismo', 'refrescante', 'O', '7_e_Meio', ...]

# %%
floresta.tagged_words()
# Out:
# [('Um', '>N+art'), ('revivalismo', 'H+n'), ...]

# %%
def simplify_tag(t):
    if "+" in t:
        return t[t.index("+")+1:]
    else:
        return t
twords = nltk.corpus.floresta.tagged_words()
twords = [(w.lower(),simplify_tag(t)) for (w,t) in twords]
twords[:10]
# Out:
# [('um', 'art'),
#  ('revivalismo', 'n'),
#  ('refrescante', 'adj'),
#  ('o', 'art'),
#  ('7_e_meio', 'prop'),
#  ('é', 'v-fin'),
#  ('um', 'art'),
#  ('ex-libris', 'n'),
#  ('de', 'prp'),
#  ('a', 'art'),
#  ('noite', 'n'),
#  ('algarvia', 'adj'),
#  ('.', '.'),
#  ('é', 'v-fin'),
#  ('uma', 'num'),
#  ('de', 'prp'),
#  ('as', 'art'),
#  ('mais', 'adv'),
#  ('antigas', 'adj'),
#  ('discotecas', 'n'),
#  ('de', 'prp'),
#  ('o', 'art'),
#  ('algarve', 'prop'),
#  (',', ','),
#  ('situada', 'v-pcp'),
#  ('em', 'prp'),
#  ('albufeira', 'prop'),
#  (',', ','),
#  ('que', 'pron-indp'),
#  ('continua', 'v-fin'),
#  ('a', 'prp'),
#  ('manter', 'v-inf'),
#  ('os', 'art'),
#  ('traços', 'n'),
#  ('decorativos', 'adj'),
#  ('e', 'conj-c'),
#  ('as', 'art'),
#  ('clientelas', 'n'),
#  ('de', 'prp'),
#  ('sempre', 'adv'),
#  ('.', '.'),
#  ('é', 'v-fin'),
#  ('um_pouco', 'adv'),
#  ('a', 'art'),
#  ('versão', 'n'),
#  ('de', 'prp'),
#  ('uma', 'art'),
#  ('espécie', 'n'),
#  ('de', 'prp'),
# ...

# %%
print (' '.join(word + '/' + tag for (word, tag) in twords[:10]))
# Out:
# um/art revivalismo/n refrescante/adj o/art 7_e_meio/prop é/v-fin um/art ex-libris/n de/prp a/art

# %%
words = floresta.words()
len(words)
# Out:
# 211852

# %%
fd = nltk.FreqDist(words)
len(fd)
# Out:
# 29421

# %%
fd.max()
# Out:
# 'de'

# %%
floresta.sents()[1]
# Out:
# ['O', '7_e_Meio', 'é', 'um', 'ex-libris', 'de', 'a', 'noite', 'algarvia', '.']

# %%
floresta.tagged_sents()
# Out:
# [[('Um', '>N+art'), ('revivalismo', 'H+n'), ('refrescante', 'N<+adj')], [('O', '>N+art'), ('7_e_Meio', 'H+prop'), ('é', 'P+v-fin'), ('um', '>N+art'), ('ex-libris', 'H+n'), ('de', 'H+prp'), ('a', '>N+art'), ('noite', 'H+n'), ('algarvia', 'N<+adj'), ('.', '.')], ...]

# %%
floresta.parsed_sents()
# Out:
# [Tree('UTT+np', [Tree('>N+art', ['Um']), Tree('H+n', ['revivalismo']), Tree('N<+adj', ['refrescante'])]), Tree('STA+fcl', [Tree('SUBJ+np', [Tree('>N+art', ['O']), Tree('H+prop', ['7_e_Meio'])]), Tree('P+v-fin', ['é']), Tree('SC+np', [Tree('>N+art', ['um']), Tree('H+n', ['ex-libris']), Tree('N<+pp', [Tree('H+prp', ['de']), Tree('P<+np', [Tree('>N+art', ['a']), Tree('H+n', ['noite']), Tree('N<+adj', ['algarvia'])])])]), Tree('.', ['.'])]), ...]

# %%
psents = floresta.parsed_sents()
psents[5].draw()

# %%
def concordance(word, context=30):
    for sent in floresta.sents():
        if word in sent:
            pos = sent.index(word)
            left = ' '.join(sent[:pos])
            right = ' '.join(sent[pos+1:])
            print('%*s %s %-*s' %\
                  (context, left[-context:], word, context, right[:context]))

# %%
concordance("dar")
# Out:
# anduru , foi o suficiente para dar a volta a o resultado .
#              1. O PÚBLICO veio dar a a imprensa diária portuguesa
#   A fartura de pensamento pode dar maus resultados e nós não quer
#                       Começa a dar resultados a política de a Uni
# ial começar a incorporar- lo e dar forma a um ' site ' que tem se
# r com Constantino para ele lhe dar também os papéis assinados .
# va a brincar , pois não lhe ia dar procuração nenhuma enquanto nã
# érica como o antídoto capaz de dar sentido a o seu enorme poder .
#           Os agentes decidiram dar vantagem a os raptores por est
# ducação_Tecnológica , sem lhes dar qualquer tipo de formação .
# o CDS , a oposição decidiu não dar acordo para que a Lei_Orgânica
#  em vésperas de o século XXI , dar novos argumentos os de a esper
# isfação que vemos a Plataforma dar razão « a_posteriori » a Álvar
#  intervenção e funcionamento , dar razão a Cunhal é também dar ra
# ...

# %%
concordance("vender")
# Out:
# er recebido uma encomenda para vender 4000 blindados a o Iraque .
# mérico_Amorim caso conseguisse vender o lote de acções de o empresár
# mpre ter jovens simpáticos a « vender » chega ! }
#        Disse que o governo vai vender « desde automóvel até particip
# ndiciou ontem duas pessoas por vender carro com ágio .
#         A intenção de Fleury é vender as ações para equilibrar as fi

# %%
from nltk.corpus import floresta

tsents = floresta.tagged_sents()
tsents = [[(w.lower(),simplify_tag(t)) for (w,t) in sent] for sent in tsents if sent]
train = tsents[100:]
test = tsents[:100]

# %%
import nltk
tagger0 = nltk.DefaultTagger('n')

# %%
nltk.accuracy(tagger0, test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-257b2dd95286> in <module>()
# ----> 1 nltk.accuracy(tagger0, test)
#
# C:\Users\TalitaCypriano\Anaconda3\lib\site-packages\nltk\metrics\scores.py in accuracy(reference, test)
#      36         same length.
#      37     """
# ---> 38     if len(reference) != len(test):
#      39         raise ValueError("Lists must have the same length.")
#      40     return sum(x == y for x, y in izip(reference, test)) / len(test)
#
# TypeError: object of type 'DefaultTagger' has no len()

# %%
tagger1 = nltk.UnigramTagger(train, backoff=tagger0)
nltk.accuracy(tagger1, test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-cd6dc175376c> in <module>()
#       1 tagger1 = nltk.UnigramTagger(train, backoff=tagger0)
# ----> 2 nltk.accuracy(tagger1, test)
#
# C:\Users\TalitaCypriano\Anaconda3\lib\site-packages\nltk\metrics\scores.py in accuracy(reference, test)
#      36         same length.
#      37     """
# ---> 38     if len(reference) != len(test):
#      39         raise ValueError("Lists must have the same length.")
#      40     return sum(x == y for x, y in izip(reference, test)) / len(test)
#
# TypeError: object of type 'UnigramTagger' has no len()

# %%
import nlpnet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a621e314cb3c> in <module>()
# ----> 1 import nlpnet
#
# ModuleNotFoundError: No module named 'nlpnet'
